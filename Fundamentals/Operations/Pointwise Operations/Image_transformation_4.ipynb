# %%
import cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
image=cv2.imread("hazy.jpg", 0)

# %%
plt.imshow(image)

# %%
image_eq = cv2.equalizeHist(image)

# %%
plt.imshow(image_eq)

# %%
image=cv2.imread("cameraman1.png",0)

# %%
image_eq = cv2.equalizeHist(image)

# %%
plt.imshow(image_eq)
