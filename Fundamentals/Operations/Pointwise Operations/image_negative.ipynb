# %%
import cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
image=cv2.imread("cameraman1.png")

# %%
plt.imshow(image)

# %%
max=np.max(image)

# %%
max
# Out:
# 253

# %%
image_n=max-image

# %%
plt.imshow(image_n)
